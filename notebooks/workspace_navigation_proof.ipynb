# %% [markdown]
# # Workspace Navigation Proof
#
# This notebook verifies that Jupyter Notebook was launched from the correct project directory (`S66-0326-Qoders-Applied-Data-Science-GrieveDash`) and that this notebook is correctly placed in the `notebooks/` folder.

# %%
import os

# Check current working directory
current_dir = os.getcwd()
print(f"Current Notebook Directory: {current_dir}")

# Verify that we are inside the 'notebooks' folder
if os.path.basename(current_dir) == "notebooks":
    print("✅ Notebook is placed in the correct 'notebooks/' folder.")
else:
    print("❌ Notebook is not in the 'notebooks/' folder. Please move it!")
# Out:
# Current Notebook Directory: /Users/apple/Documents/S66-0326-Qoders-Applied-Data-Science-GrieveDash/notebooks
# ✅ Notebook is placed in the correct 'notebooks/' folder.

# %%
import datetime

print(f"Kernel executed successfully at: {datetime.datetime.now()}")
print("Workspace setup is complete and functioning.")
# Out:
# Kernel executed successfully at: 2026-04-06 15:09:20.121219
# Workspace setup is complete and functioning.
